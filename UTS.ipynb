# %% [markdown]
# <h1>UJIAN TENGAH SEMESTER</h1>
# <h3>Nama: AHMAD HAMDANI</h3>
# <h3>NIM: 233307092</h3>

# %% [markdown]
# 1. Instalasi library dapat dilakukan dengan perintah `pip install` diikuti oleh nama library dan versi yang diinginkan, kemudian diverifikasi dengan mengimpor library serta mengecek versinya. Setelah di impor tampilkan versi dari library tersebut.

# %%
import pandas as pd
import numpy as np
import missingno as msno
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
from sklearn.impute import SimpleImputer
from wordcloud import WordCloud

print(f"Versi pandas {pd.__version__}")
print(f"Versi numpy {np.__version__}")
print(f"Versi missingno {msno.__version__}")
print(f"Versi matplotlib {mpl.__version__}")
print(f"Versi seaborn {sns.__version__}")
# Out:
# Versi pandas 2.2.3
# Versi numpy 2.2.3
# Versi missingno 0.5.2
# Versi matplotlib 3.10.1
# Versi seaborn 0.13.2

# %% [markdown]
# <h2>Memahami Struktur Dataset</h2>

# %% [markdown]
# 2. Gunakan fungsi `read_csv` pada `library` pandas untuk membaca dataset `supermarket` dari file CSV bernama `supermarket.csv` yang berada dalam folder data, lalu menampilkan seluruh isi DataFrame tersebut. Jika dataset berukuran besar, Pandas hanya akan menampilkan sebagian data (beberapa baris awal dan akhir) untuk efisiensi tampilan.

# %%
supermarket = pd.read_csv('data/supermarket.csv')
supermarket
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %% [markdown]
# 3. Gunakan fungsi `head()` yang digunakan untuk menampilkan lima baris pertama dari DataFrame `supermarket`, sehingga memberikan gambaran awal tentang struktur dan isi dataset, termasuk kolom yang tersedia serta beberapa nilai awal dari setiap kolom.

# %%
supermarket.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %% [markdown]
# 4. Gunakan fungsi `tail()` yang digunakan untuk menampilkan lima baris terakhir dari DataFrame `supermarket`, sehingga memberikan gambaran akhir dari isi dataset, termasuk kolom yang tersedia dan nilai pada baris-baris terakhir.

# %%
supermarket.tail()
# Out:
#            Ship Mode   Segment        Country         City       State  \
# 9989    Second Class  Consumer  United States        Miami     Florida
# 9990  Standard Class  Consumer  United States   Costa Mesa  California
# 9991  Standard Class  Consumer  United States   Costa Mesa  California
# 9992  Standard Class  Consumer  United States   Costa Mesa  California
# 9993    Second Class  Consumer  United States  Westminster  California
#
#       Postal Code Region         Category Sub-Category    Sales  Quantity  \
# 9989        33180  South        Furniture  Furnishings   25.248         3
# 9990        92627   West        Furniture  Furnishings   91.960         2
# 9991        92627   West       Technology       Phones  258.576         2
# 9992        92627   West  Office Supplies        Paper   29.600         4
# 9993        92683   West  Office Supplies   Appliances  243.160         2
#
#       Discount   Profit
# 9989       0.2   4.1028
# 9990       0.0  15.6332
# ...

# %% [markdown]
# 5. Gunakan fungsi `nunique()` yang digunakan untuk mendapatkan informasi Dataset supermarket yang memiliki 13 kolom dengan variasi unik dalam kategori produk, metode pengiriman, lokasi geografis, serta nilai penjualan, diskon, dan profit, yang dapat dianalisis lebih lanjut untuk memahami tren penjualan dan segmentasi pelanggan.

# %%
supermarket.nunique()
# Out:
# Ship Mode          4
# Segment            3
# Country            1
# City             531
# State             49
# Postal Code      631
# Region             4
# Category           3
# Sub-Category      17
# Sales           5825
# Quantity          14
# Discount          12
# Profit          7287
# dtype: int64

# %% [markdown]
# 6. Gunakan fungsi `isnull()` dan jumlahkan fungsi `sum()` untuk mengetahui informasi apakah ada kolom kosong pada Dataset. Namun, Dataset supermarket tidak memiliki nilai kosong (missing values) di semua kolom, sehingga dapat langsung digunakan untuk analisis tanpa perlu penanganan data yang hilang.

# %%
supermarket.isnull().sum()
# Out:
# Ship Mode       0
# Segment         0
# Country         0
# City            0
# State           0
# Postal Code     0
# Region          0
# Category        0
# Sub-Category    0
# Sales           0
# Quantity        0
# Discount        0
# Profit          0
# dtype: int64

# %% [markdown]
# 7. Panggil variabel `supermarket` lalu tampilkan informasi dataset tersebut dengan fungsi `info()` yang digunakan untuk menampilkan ringkasan struktur DataFrame supermarket, termasuk jumlah baris, jumlah kolom, nama kolom, jumlah nilai non-null di setiap kolom, tipe data masing-masing kolom, serta penggunaan memori DataFrame tersebut.

# %%
supermarket.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %% [markdown]
# 8. Setelah itu, gunakan fungsi `describe()` untuk menghasilkan ringkasan statistik dari dataset supermarket, termasuk jumlah data (count), rata-rata (mean), standar deviasi (std), nilai minimum (min), kuartil pertama (25%), median (50%), kuartil ketiga (75%), dan nilai maksimum (max) untuk setiap kolom numerik dalam dataset tersebut.

# %%
supermarket.describe()
# Out:
#         Postal Code         Sales     Quantity     Discount       Profit
# count   9994.000000   9994.000000  9994.000000  9994.000000  9994.000000
# mean   55190.379428    229.858001     3.789574     0.156203    28.656896
# std    32063.693350    623.245101     2.225110     0.206452   234.260108
# min     1040.000000      0.444000     1.000000     0.000000 -6599.978000
# 25%    23223.000000     17.280000     2.000000     0.000000     1.728750
# 50%    56430.500000     54.490000     3.000000     0.200000     8.666500
# 75%    90008.000000    209.940000     5.000000     0.200000    29.364000
# max    99301.000000  22638.480000    14.000000     0.800000  8399.976000

# %% [markdown]
# 9. Gunakan library `missingno` dan fungsi `bar()` untuk menampilkan informasi missing values. Namun, Grafik dibawah ini menunjukkan bahwa semua kolom dalam dataset memiliki jumlah data yang lengkap tanpa nilai yang hilang.

# %%
msno.bar(supermarket)
# Out:
# <Axes: >

# %% [markdown]
# 10. Perintah `msno.matrix(supermarket)` yang bersumber dari library `missingno` akan menampilkan visualisasi matriks yang menunjukkan keberadaan atau ketiadaan data dalam dataset, dengan baris mewakili setiap entri dan warna yang menunjukkan apakah ada nilai yang hilang atau tidak. Namun pada grafik di bawah ini menunjukan tidak ada missing values

# %%
msno.matrix(supermarket)
# Out:
# <Axes: >

# %% [markdown]
# 11. Kode `print(f"Jumlah data duplikat: {supermarket.duplicated().sum()}")` menghitung dan mencetak jumlah baris duplikat dalam dataset `supermarket`, dengan hasil menunjukkan bahwa terdapat **17 baris duplikat**.

# %%
print(f"Jumlah data duplikat: {supermarket.duplicated().sum()}")
# Out:
# Jumlah data duplikat: 17

# %% [markdown]
# 12. Pada Kode `supermarket.groupby(by="Nama Kolom")["Nama Kolom"].count()` digunakan untuk mengelompokkan data berdasarkan kolom `Ship Mode, State, Region, Category` secara terpisah dan menghitung jumlah kemunculan masing-masing kategori dalam kolom tersebut.

# %%
supermarket.groupby(by="Ship Mode")["Ship Mode"].count()
# Out:
# Ship Mode
# First Class       1538
# Same Day           543
# Second Class      1945
# Standard Class    5968
# Name: Ship Mode, dtype: int64

# %%
supermarket.groupby(by="State")["State"].count()
# Out:
# State
# Alabama                   61
# Arizona                  224
# Arkansas                  60
# California              2001
# Colorado                 182
# Connecticut               82
# Delaware                  96
# District of Columbia      10
# Florida                  383
# Georgia                  184
# Idaho                     21
# Illinois                 492
# Indiana                  149
# Iowa                      30
# Kansas                    24
# Kentucky                 139
# Louisiana                 42
# Maine                      8
# Maryland                 105
# Massachusetts            135
# Michigan                 255
# Minnesota                 89
# Mississippi               53
# Missouri                  66
# Montana                   15
# Nebraska                  38
# Nevada                    39
# New Hampshire             27
# New Jersey               130
# New Mexico                37
# New York                1128
# North Carolina           249
# ...

# %%
supermarket.groupby(by="Region")["Region"].count()
# Out:
# Region
# Central    2323
# East       2848
# South      1620
# West       3203
# Name: Region, dtype: int64

# %%
supermarket.groupby(by="Category")["Category"].count()
# Out:
# Category
# Furniture          2121
# Office Supplies    6026
# Technology         1847
# Name: Category, dtype: int64

# %% [markdown]
# 13. Visualisasi Data dengan library `matplotlib` yang bertujuan untuk membuat visualisasi jumlah data berdasarkan kategori `Ship Mode, State, Region, Category` dalam dataset "supermarket" menggunakan countplot dari Seaborn, dengan palet warna "coolwarm" serta menambahkan judul dan label sumbu untuk memperjelas informasi yang ditampilkan.

# %%
# Visualisasi jumlah data berdasarkan type
plt.figure(figsize=(8, 5))
sns.countplot(x='Ship Mode', data=supermarket, palette='coolwarm')

# Menambahkan judul dan label
plt.title("Distribusi Konten Berdasarkan Ship Mode")
plt.xlabel("Ship Mode Konten")
plt.ylabel("Jumlah")

# Menampilkan plot
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_15628\2404781541.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Ship Mode', data=supermarket, palette='coolwarm')

# %%
# Visualisasi jumlah data berdasarkan type
plt.figure(figsize=(8, 5))
sns.countplot(x='Region', data=supermarket, palette='coolwarm')

# Menambahkan judul dan label
plt.title("Distribusi Konten Berdasarkan Region")
plt.xlabel("Region Konten")
plt.ylabel("Jumlah")

# Menampilkan plot
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_15628\1557775670.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Region', data=supermarket, palette='coolwarm')

# %%
# Visualisasi jumlah data berdasarkan type
plt.figure(figsize=(14, 5))
sns.countplot(x='State', data=supermarket, palette='coolwarm')

# Menambahkan judul dan label
plt.title("Distribusi Konten Berdasarkan State")
plt.xlabel("State Konten")
plt.xticks(rotation=90) 
plt.ylabel("Jumlah")

# Menampilkan plot
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_15628\2813954328.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='State', data=supermarket, palette='coolwarm')

# %%
# Visualisasi jumlah data berdasarkan type
plt.figure(figsize=(14, 5))
sns.countplot(x='Category', data=supermarket, palette='coolwarm')

# Menambahkan judul dan label
plt.title("Distribusi Konten Berdasarkan Category")
plt.xlabel("Category Konten")
plt.ylabel("Jumlah")

# Menampilkan plot
plt.show()
# Out:
# C:\Users\ACER\AppData\Local\Temp\ipykernel_15628\3750405090.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x='Category', data=supermarket, palette='coolwarm')

# %%
# Menghitung jumlah konten berdasarkan tahun dan tipe
grouped_df = supermarket.groupby(["Region", "Category"]).size().reset_index(name="count")

# Plot sebagai line chart
plt.figure(figsize=(14, 6))
sns.lineplot(x="Region", y="count", hue="Category", data=grouped_df, marker="o", palette="coolwarm")

# Perbaikan tampilan
plt.title("Tren Jumlah Konten Berdasarkan Tahun Rilis dan Tipe", fontsize=14)
plt.xlabel("Tahun Rilis", fontsize=12)
plt.ylabel("Jumlah Konten", fontsize=12)
plt.xticks(rotation=45) 
plt.grid(axis="y", linestyle="--", alpha=0.5) 
plt.legend(title="Tipe Konten")

# Menampilkan plot
plt.show()

# %%
# Asumsikan 'acara_tv_amputasi' adalah dataframe asli
plt.figure(figsize=(16, 6))

# Visualisasi dengan countplot
sns.countplot(x="Region", hue="Category", data=supermarket, palette="coolwarm", alpha=0.8)

# Perbaikan tampilan
plt.title("Perbandingan Jumlah Konten Berdasarkan Tahun Rilis dan Tipe", fontsize=14)
plt.xlabel("Tahun Rilis", fontsize=12)
plt.ylabel("Jumlah Konten", fontsize=12)
plt.xticks(rotation=90) 
plt.grid(axis="y", linestyle="--", alpha=0.5) 
plt.legend(title="Tipe Konten")

# Menampilkan plot
plt.show()

# %%
# Menghitung jumlah data berdasarkan kategori rating
rating_counts = supermarket["Region"].value_counts()

# Membuat Pie Chart
plt.figure(figsize=(8, 6))
plt.pie(rating_counts, labels=rating_counts.index, autopct="%1.1f%%", colors=plt.cm.Paired.colors)
plt.title("Distribusi Rating Konten")
plt.axis("equal")  # Agar pie chart berbentuk lingkaran

# Menampilkan hasil
plt.show()

# %%
# Menghitung jumlah data berdasarkan kategori rating
rating_counts = supermarket["Category"].value_counts()

# Membuat Pie Chart
plt.figure(figsize=(8, 6))
plt.pie(rating_counts, labels=rating_counts.index, autopct="%1.1f%%", colors=plt.cm.Paired.colors)
plt.title("Distribusi Rating Konten")
plt.axis("equal")  # Agar pie chart berbentuk lingkaran

# Menampilkan hasil
plt.show()

# %%
# Menghitung jumlah data berdasarkan kategori rating
rating_counts = supermarket["State"].value_counts()

# Membuat Histogram Plot
plt.figure(figsize=(10, 6))
sns.histplot(data=supermarket, x="State", discrete=True, bins=len(rating_counts), shrink=0.8, color="skyblue")

plt.xlabel("Rating Konten")
plt.ylabel("Jumlah")
plt.title("Distribusi Rating Konten")
plt.xticks(rotation=90)  # Memiringkan label untuk keterbacaan

# Menampilkan hasil
plt.show()

# %%
# Menghitung jumlah data berdasarkan kategori rating
rating_counts = supermarket["Category"].value_counts()

# Membuat Histogram Plot
plt.figure(figsize=(10, 6))
sns.histplot(data=supermarket, x="Category", discrete=True, bins=len(rating_counts), shrink=0.8, color="skyblue")

plt.xlabel("Rating Konten")
plt.ylabel("Jumlah")
plt.title("Distribusi Rating Konten")
plt.xticks(rotation=45)  # Memiringkan label untuk keterbacaan

# Menampilkan hasil
plt.show()

# %%
# Menghitung jumlah data berdasarkan kategori rating
rating_counts = supermarket["Region"].value_counts()

# Membuat Histogram Plot
plt.figure(figsize=(10, 6))
sns.histplot(data=supermarket, x="Region", discrete=True, bins=len(rating_counts), shrink=0.8, color="skyblue")

plt.xlabel("Rating Konten")
plt.ylabel("Jumlah")
plt.title("Distribusi Rating Konten")
plt.xticks(rotation=45)  # Memiringkan label untuk keterbacaan

# Menampilkan hasil
plt.show()

# %%
# Pastikan ada kolom 'Category' yang membedakan antara jenis produk
if 'Category' in supermarket.columns:
    # Hitung jumlah produk per kategori dalam setiap State
    Furniture = supermarket[supermarket['Category'] == 'Furniture']['State'].value_counts().sort_index()
    Office_Supplies = supermarket[supermarket['Category'] == 'Office Supplies']['State'].value_counts().sort_index()
    Technology = supermarket[supermarket['Category'] == 'Technology']['State'].value_counts().sort_index()

    # Urutkan berdasarkan alfabet (A-Z)
    sorted_states = sorted(set(supermarket['State']))  # Dapatkan daftar State dalam urutan abjad

    # Pastikan semua State ada dalam setiap kategori (isi 0 jika tidak ada)
    Furniture = Furniture.reindex(sorted_states, fill_value=0)
    Office_Supplies = Office_Supplies.reindex(sorted_states, fill_value=0)
    Technology = Technology.reindex(sorted_states, fill_value=0)

    # Plot line chart
    plt.figure(figsize=(14, 6))
    plt.plot(Furniture.index, Furniture.values, marker='o', linestyle='-', label='Furniture', color='blue')
    plt.plot(Office_Supplies.index, Office_Supplies.values, marker='o', linestyle='-', label='Office Supplies', color='red')
    plt.plot(Technology.index, Technology.values, marker='o', linestyle='-', label='Technology', color='yellow')

    plt.xlabel('State')
    plt.ylabel('Jumlah Produk')
    plt.title('Perbandingan Jumlah Produk per Kategori di Setiap State')
    plt.xticks(rotation=90)
    plt.legend()
    plt.grid(True, linestyle='--', alpha=0.7)

    plt.show()
